# %%
from docx import *

# %%
doc = Document("testing.docx")

doc.add_heading("hi andrew",level=4)
doc.add_heading("hi andrew",level=2)
doc.add_heading("hi andrew",level=1)
doc.add_heading("hi andrew",level=0)
img = doc.add_picture(image_path_or_stream="C:\\Users\\AUTHENTIC PLUS STORE\\Desktop\\goals for the holidays\\sleepy panda\\cv maker\\useful.png")
doc.add_page_break()
doc.add_paragraph("this is me randomly learning as i  go :) cause i refused to read the docs")

doc.save("testing2.docx")
